# %%
# %load_ext autoreload
# %autoreload 2
import chainertools
import os
import glob
chainertools.init()
import settings

# %%
chainertools.plot.plot(glob.glob(os.path.join(settings.log_directory, 'snv*batch128*')),
                      ys=['loss', 'accuracy', 'eta', 'samples_per_s'],
                      y_range="train,val")
# Out:
# (<Figure size 1728x1152 with 8 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f67143c9390>,
# ...
#        dtype=object))
